# %% [markdown]
# + 좌우 반전

# %%
import cv2

# %%
cap = cv2.VideoCapture('4-5.mp4') # 입력할 영상 경로 + 파일명 입력
 
count = 799
 
while(cap.isOpened()):
    ret, image = cap.read()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # grayscale변환
    image = cv2.flip(image, 1)
    
#     height, width = image.shape
#     matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 0.5)
#     image = cv2.warpAffine(image, matrix, (width, height))
    
    cv2.imwrite("4_frame/frameS%d.jpg" %count, image)
    print('Saved frame%d.jpg' %count)
    count += 1
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break 
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Saved frame799.jpg
# Saved frame800.jpg
# Saved frame801.jpg
# Saved frame802.jpg
# Saved frame803.jpg
# Saved frame804.jpg
# Saved frame805.jpg
# Saved frame806.jpg
# Saved frame807.jpg
# Saved frame808.jpg
# Saved frame809.jpg
# Saved frame810.jpg
# Saved frame811.jpg
# Saved frame812.jpg
# Saved frame813.jpg
# Saved frame814.jpg
# Saved frame815.jpg
# Saved frame816.jpg
# Saved frame817.jpg
# Saved frame818.jpg
# Saved frame819.jpg
# Saved frame820.jpg
# Saved frame821.jpg
# Saved frame822.jpg
# Saved frame823.jpg
# Saved frame824.jpg
# Saved frame825.jpg
# Saved frame826.jpg
# Saved frame827.jpg
# Saved frame828.jpg
# Saved frame829.jpg
# Saved frame830.jpg
# Saved frame831.jpg
# Saved frame832.jpg
# Saved frame833.jpg
# Saved frame834.jpg
# Saved frame835.jpg
# Saved frame836.jpg
# Saved frame837.jpg
# Saved frame838.jpg
# Saved frame839.jpg
# Saved frame840.jpg
# Saved frame841.jpg
# Saved frame842.jpg
# Saved frame843.jpg
# Saved frame844.jpg
# Saved frame845.jpg
# Saved frame846.jpg
# Saved frame847.jpg
# Saved frame848.jpg
# Saved frame849.jpg
# Saved frame850.jpg
# Saved frame851.jpg
# Saved frame852.jpg
# Saved frame853.jpg
# Saved frame854.jpg
# Saved frame855.jpg
# Saved frame856.jpg
# Saved frame857.jpg
# Saved frame858.jpg
# Saved frame859.jpg
# Saved frame860.jpg
# Saved frame861.jpg
# Saved frame862.jpg
# Saved frame863.jpg
# Saved frame864.jpg
# Saved frame865.jpg
# Saved frame866.jpg
# Saved frame867.jpg
# Saved frame868.jpg
# Saved frame869.jpg
# Saved frame870.jpg
# Saved frame871.jpg
# Saved frame872.jpg
# Saved frame873.jpg
# Saved frame874.jpg
# Saved frame875.jpg
# Saved frame876.jpg
# Saved frame877.jpg
# Saved frame878.jpg
# Saved frame879.jpg
# Saved frame880.jpg
# Saved frame881.jpg
# Saved frame882.jpg
# Saved frame883.jpg
# Saved frame884.jpg
# Saved frame885.jpg
# Saved frame886.jpg
# Saved frame887.jpg
# Saved frame888.jpg
# Saved frame889.jpg
# Saved frame890.jpg
# Saved frame891.jpg
# Saved frame892.jpg
# Saved frame893.jpg
# Saved frame894.jpg
# Saved frame895.jpg
# Saved frame896.jpg
# Saved frame897.jpg
# Saved frame898.jpg
# Saved frame899.jpg
# Saved frame900.jpg
# Saved frame901.jpg
# Saved frame902.jpg
# Saved frame903.jpg
# Saved frame904.jpg
# Saved frame905.jpg
# Saved frame906.jpg
# Saved frame907.jpg
# Saved frame908.jpg
# Saved frame909.jpg
# Saved frame910.jpg
# Saved frame911.jpg
# Saved frame912.jpg
# Saved frame913.jpg
# Saved frame914.jpg
# Saved frame915.jpg
# Saved frame916.jpg
# Saved frame917.jpg
# Saved frame918.jpg
# Saved frame919.jpg
# Saved frame920.jpg
# Saved frame921.jpg
# Saved frame922.jpg
# Saved frame923.jpg
# Saved frame924.jpg
# Saved frame925.jpg
# Saved frame926.jpg
# Saved frame927.jpg
# Saved frame928.jpg
# Saved frame929.jpg
# Saved frame930.jpg
# Saved frame931.jpg
# Saved frame932.jpg
# Saved frame933.jpg
# Saved frame934.jpg
# Saved frame935.jpg
# Saved frame936.jpg
# Saved frame937.jpg
# Saved frame938.jpg
# Saved frame939.jpg
# Saved frame940.jpg
# Saved frame941.jpg
# Saved frame942.jpg
# Saved frame943.jpg
# Saved frame944.jpg
# Saved frame945.jpg
# Saved frame946.jpg
# Saved frame947.jpg
# Saved frame948.jpg
# Saved frame949.jpg
# Saved frame950.jpg
# Saved frame951.jpg
# Saved frame952.jpg
# Saved frame953.jpg
# Saved frame954.jpg
# Saved frame955.jpg
# Saved frame956.jpg
# Saved frame957.jpg
# Saved frame958.jpg
# Saved frame959.jpg
# Saved frame960.jpg
# Saved frame961.jpg
# Saved frame962.jpg
# Saved frame963.jpg
# Saved frame964.jpg
# Saved frame965.jpg
# Saved frame966.jpg
# Saved frame967.jpg
# Saved frame968.jpg
# Saved frame969.jpg
# Saved frame970.jpg
# Saved frame971.jpg
# Saved frame972.jpg
# Saved frame973.jpg
# Saved frame974.jpg
# Saved frame975.jpg
# Saved frame976.jpg
# Saved frame977.jpg
# Saved frame978.jpg
# Saved frame979.jpg
# Saved frame980.jpg
# Saved frame981.jpg
# Saved frame982.jpg
# Saved frame983.jpg
# Saved frame984.jpg
# Saved frame985.jpg
# Saved frame986.jpg
# Saved frame987.jpg
# Saved frame988.jpg
# Saved frame989.jpg
# Saved frame990.jpg
# Saved frame991.jpg
# Saved frame992.jpg
# Saved frame993.jpg
# Saved frame994.jpg
# Saved frame995.jpg
# Saved frame996.jpg
# Saved frame997.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-6354b1a3ed42> in <module>
#       5 while(cap.isOpened()):
#       6     ret, image = cap.read()
# ----> 7     image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # grayscale변환
#       8     image = cv2.flip(image, 1)
#       9
#
# error: OpenCV(3.4.2) c:\projects\opencv-python\opencv\modules\imgproc\src\color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'cv::CvtHelper<struct cv::Set<3,4,-1>,struct cv::Set<1,-1,-1>,struct cv::Set<0,2,5>,2>::CvtHelper'
